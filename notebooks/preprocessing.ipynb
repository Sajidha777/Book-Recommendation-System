# %%
import pandas as pd
import numpy as np
import requests
import spacy
import re
from collections import Counter

# %%
import nltk
from nltk.stem import PorterStemmer
from tqdm import tqdm
from nltk.tokenize import word_tokenize
from nltk import bigrams, word_tokenize

# %%
books = pd.read_csv('../data/cleaned_books.zip')

# %%
books.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                                                image  \
# 0  http://books.google.com/books/content?id=IjvHQ...
# 1  http://books.google.com/books/content?id=2tsDA...
# 2  http://books.google.com/books/content?id=aRSIg...
# 3  http://books.google.com/books/content?id=kVqRa...
# 4  http://books.google.com/books/content?id=lmLqA...
#
#                     authors                     categories  \
# 0            ['Philip Nel']  ['Biography & Autobiography']
# 1          ['David R. Ray']                   ['Religion']
# 2       ['Veronica Haddon']                    ['Fiction']
# 3      ['Everett Ferguson']                   ['Religion']
# 4  ['Mary Fabyan Windeatt']  ['Biography & Autobiography']
#
#                     publisher  \
# 0                   A&C Black
# 1                         NaN
# 2                   iUniverse
# 3  Wm. B. Eerdmans Publishing
# 4             Tan Books & Pub
#
#                                          description
# 0  Philip Nel takes a fascinating look into the k...
# 1  This resource includes twelve principles in un...
# 2  Julia Thomas finds her life spinning out of co...
# 3  In The Church of Christ: A Biblical Ecclesiolo...
# 4  The story for children 10 and up of St. Hyacin...

# %%
books['tags'] = books['description']

# %%
#CONVERT ALL TO ONE LINER
books['tags'] = books['tags'].replace('\n', ' ')

# %%
#REMOVE SPECIAL CHARACTERS, PUNCTUATIONS, CONVERT TO LOWER, SPACE REDUCTING
books["tags"] = books["tags"].str.replace("[^a-zA-Z0-9 ]", " ", regex=True)
books["tags"] = books["tags"].str.lower()
books["tags"] = books["tags"].str.replace("\s+", " ", regex=True)

# %%
books.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                                                image  \
# 0  http://books.google.com/books/content?id=IjvHQ...
# 1  http://books.google.com/books/content?id=2tsDA...
# 2  http://books.google.com/books/content?id=aRSIg...
# 3  http://books.google.com/books/content?id=kVqRa...
# 4  http://books.google.com/books/content?id=lmLqA...
#
#                     authors                     categories  \
# 0            ['Philip Nel']  ['Biography & Autobiography']
# 1          ['David R. Ray']                   ['Religion']
# 2       ['Veronica Haddon']                    ['Fiction']
# 3      ['Everett Ferguson']                   ['Religion']
# 4  ['Mary Fabyan Windeatt']  ['Biography & Autobiography']
#
#                     publisher  \
# 0                   A&C Black
# 1                         NaN
# 2                   iUniverse
# 3  Wm. B. Eerdmans Publishing
# 4             Tan Books & Pub
#
#                                          description  \
# 0  Philip Nel takes a fascinating look into the k...
# 1  This resource includes twelve principles in un...
# 2  Julia Thomas finds her life spinning out of co...
# 3  In The Church of Christ: A Biblical Ecclesiolo...
# 4  The story for children 10 and up of St. Hyacin...
#
#                                                 tags
# 0  philip nel takes a fascinating look into the k...
# 1  this resource includes twelve principles in un...
# 2  julia thomas finds her life spinning out of co...
# 3  in the church of christ a biblical ecclesiolog...
# 4  the story for children 10 and up of st hyacint...

# %%
books = books.drop(columns=['image','publisher','description'],axis =1)

# %%
#TOKENIZE the tags column
books['tags'] = books['tags'].apply(lambda x: x.split())

# %%
books.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                     authors                     categories  \
# 0            ['Philip Nel']  ['Biography & Autobiography']
# 1          ['David R. Ray']                   ['Religion']
# 2       ['Veronica Haddon']                    ['Fiction']
# 3      ['Everett Ferguson']                   ['Religion']
# 4  ['Mary Fabyan Windeatt']  ['Biography & Autobiography']
#
#                                                 tags
# 0  [philip, nel, takes, a, fascinating, look, int...
# 1  [this, resource, includes, twelve, principles,...
# 2  [julia, thomas, finds, her, life, spinning, ou...
# 3  [in, the, church, of, christ, a, biblical, ecc...
# 4  [the, story, for, children, 10, and, up, of, s...

# %%
#REMOVE STOPWORDS
#stopwords
stopwords_list = requests.get("https://gist.githubusercontent.com/rg089/35e00abf8941d72d419224cfd5b5925d/raw/12d899b70156fd0041fa9778d657330b024b959c/stopwords.txt").content
stopwords = list(stopwords_list.decode().splitlines())

# %%
def remove_stopwords(tokens):
    return [token for token in tokens if token not in stopwords]

# Apply the function to the 'tokens' column
books['tags'] = books['tags'].apply(remove_stopwords)

# %%
books.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                     authors                     categories  \
# 0            ['Philip Nel']  ['Biography & Autobiography']
# 1          ['David R. Ray']                   ['Religion']
# 2       ['Veronica Haddon']                    ['Fiction']
# 3      ['Everett Ferguson']                   ['Religion']
# 4  ['Mary Fabyan Windeatt']  ['Biography & Autobiography']
#
#                                                 tags
# 0  [philip, nel, takes, fascinating, key, aspects...
# 1  [resource, includes, principles, understanding...
# 2  [julia, thomas, finds, life, spinning, control...
# 3  [church, christ, biblical, ecclesiology, today...
# 4  [story, children, 10, hyacinth, dominican, pla...

# %%
#REMOVE NUMBERIC TOKENS
books['tags'] = books['tags'].apply(lambda tokens: [token for token in tokens if not token.isdigit()])

# %%
#REMOVE ENGLISH FIRST NAMES
nlp = spacy.load("en_core_web_sm")
def remove_names(tokens):
    doc = nlp(' '.join(tokens))
    return [token.text for token in doc if token.ent_type_ != 'PERSON']

# Apply the function to the 'tags' column
books['tags_without_names'] = books['tags'].apply(remove_names)

# %%
books.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                     authors                     categories  \
# 0            ['Philip Nel']  ['Biography & Autobiography']
# 1          ['David R. Ray']                   ['Religion']
# 2       ['Veronica Haddon']                    ['Fiction']
# 3      ['Everett Ferguson']                   ['Religion']
# 4  ['Mary Fabyan Windeatt']  ['Biography & Autobiography']
#
#                                                 tags  \
# 0  ['philip', 'nel', 'takes', 'fascinating', 'key...
# 1  ['resource', 'includes', 'principles', 'unders...
# 2  ['julia', 'thomas', 'finds', 'life', 'spinning...
# 3  ['church', 'christ', 'biblical', 'ecclesiology...
# 4  ['story', 'children', 'hyacinth', 'dominican',...
#
#                                   tags_without_names
# 0  ['takes', 'fascinating', 'key', 'aspects', 'se...
# 1  ['resource', 'includes', 'principles', 'unders...
# 2  ['finds', 'life', 'spinning', 'control', 'deat...
# 3  ['church', 'christ', 'biblical', 'ecclesiology...
# 4  ['story', 'children', 'hyacinth', 'dominican',...

# %%
books['tags'] = books['tags_without_names']

# %%
books = books.drop('tags_without_names', axis =1)

# %%
books.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                     authors                     categories  \
# 0            ['Philip Nel']  ['Biography & Autobiography']
# 1          ['David R. Ray']                   ['Religion']
# 2       ['Veronica Haddon']                    ['Fiction']
# 3      ['Everett Ferguson']                   ['Religion']
# 4  ['Mary Fabyan Windeatt']  ['Biography & Autobiography']
#
#                                                 tags
# 0  ['takes', 'fascinating', 'key', 'aspects', 'se...
# 1  ['resource', 'includes', 'principles', 'unders...
# 2  ['finds', 'life', 'spinning', 'control', 'deat...
# 3  ['church', 'christ', 'biblical', 'ecclesiology...
# 4  ['story', 'children', 'hyacinth', 'dominican',...

# %%
# Function to convert to string, handling empty strings
import ast
def tokens_string(s):
    try:
        lst = ast.literal_eval(s)
        if isinstance(lst, list) and len(lst) > 0:
            return ' '.join(lst)
        else:
            return ''
    except (SyntaxError, ValueError):
        return ''

# %%
books['tags'] = books['tags'].apply(lambda x: tokens_string(x))

# %%
books.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                     authors                     categories  \
# 0            ['Philip Nel']  ['Biography & Autobiography']
# 1          ['David R. Ray']                   ['Religion']
# 2       ['Veronica Haddon']                    ['Fiction']
# 3      ['Everett Ferguson']                   ['Religion']
# 4  ['Mary Fabyan Windeatt']  ['Biography & Autobiography']
#
#                                                 tags
# 0  takes fascinating key aspects seuss career poe...
# 1  resource includes principles understanding sma...
# 2  finds life spinning control death husband turn...
# 3  church christ biblical ecclesiology today resp...
# 4  story children hyacinth dominican planted fait...

# %%
books['stemmed_tags'] = books['tags']

# %%
#STEMMING
# Initialize the Porter Stemmer
stemmer = PorterStemmer()
# Function to apply stemming to a single text
def stem_text(text):
    return ' '.join(stemmer.stem(word) for word in text.split())
# Create a tqdm progress bar to track progress
tqdm.pandas()
# Apply stemming to a batch of 1000 rows
start_index = 0
batch_size = 10000
while start_index < len(books):
    end_index = start_index + batch_size
    books['stemmed_tags'].iloc[start_index:end_index] = books['tags'].iloc[start_index:end_index].progress_apply(stem_text)
    start_index = end_index
# Out:
# 100%|██████████| 10000/10000 [00:11<00:00, 835.19it/s]
# 100%|██████████| 10000/10000 [00:11<00:00, 856.29it/s]
# 100%|██████████| 10000/10000 [00:11<00:00, 866.59it/s]
# 100%|██████████| 10000/10000 [00:11<00:00, 869.35it/s]
# 100%|██████████| 10000/10000 [00:13<00:00, 751.17it/s]
# 100%|██████████| 10000/10000 [00:13<00:00, 751.39it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 832.11it/s]
# 100%|██████████| 10000/10000 [00:11<00:00, 838.61it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 798.25it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 807.66it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 801.70it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 780.95it/s]
# 100%|██████████| 10000/10000 [00:12<00:00, 796.41it/s]
# 100%|██████████| 10000/10000 [00:20<00:00, 495.72it/s]
# 100%|██████████| 3505/3505 [00:06<00:00, 573.29it/s]

# %%
books.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                     authors                     categories  \
# 0            ['Philip Nel']  ['Biography & Autobiography']
# 1          ['David R. Ray']                   ['Religion']
# 2       ['Veronica Haddon']                    ['Fiction']
# 3      ['Everett Ferguson']                   ['Religion']
# 4  ['Mary Fabyan Windeatt']  ['Biography & Autobiography']
#
#                                                 tags  \
# 0  takes fascinating key aspects seuss career poe...
# 1  resource includes principles understanding sma...
# 2  finds life spinning control death husband turn...
# 3  church christ biblical ecclesiology today resp...
# 4  story children hyacinth dominican planted fait...
#
#                                         stemmed_tags
# 0  take fascin key aspect seuss career poetri pol...
# 1  resourc includ principl understand small churc...
# 2  find life spin control death husband turn mini...
# 3  church christ biblic ecclesiolog today respect...
# 4  stori children hyacinth dominican plant faith ...

# %%
#LEMMATIZE
# Load the spaCy English model
nlp = spacy.load('en_core_web_sm')

books['text_lemma'] = np.nan
lemma_text_list = []

batch_size = 100

num_batches = (len(books) + batch_size - 1) // batch_size

#usin tqdm to create a progress bar
for i in tqdm(range(num_batches), desc="Processing batches"):
    start_idx = i * batch_size
    end_idx = (i + 1) * batch_size
    batch_docs = list(nlp.pipe(books["tags"].iloc[start_idx:end_idx],n_process=-1))

    for doc in tqdm(batch_docs, desc="Lemmatizing", leave=False):
        lemma_text_list.append(" ".join(token.lemma_ for token in doc))

books["tags_lemma"] = lemma_text_list
# Out:
# Processing batches: 100%|██████████| 1436/1436 [36:26<00:00,  1.52s/it]

# %%
books.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                     authors                     categories  \
# 0            ['Philip Nel']  ['Biography & Autobiography']
# 1          ['David R. Ray']                   ['Religion']
# 2       ['Veronica Haddon']                    ['Fiction']
# 3      ['Everett Ferguson']                   ['Religion']
# 4  ['Mary Fabyan Windeatt']  ['Biography & Autobiography']
#
#                                                 tags  \
# 0  takes fascinating key aspects seuss career poe...
# 1  resource includes principles understanding sma...
# 2  finds life spinning control death husband turn...
# 3  church christ biblical ecclesiology today resp...
# 4  story children hyacinth dominican planted fait...
#
#                                         stemmed_tags  \
# 0  take fascin key aspect seuss career poetri pol...
# 1  resourc includ principl understand small churc...
# 2  find life spin control death husband turn mini...
# 3  church christ biblic ecclesiolog today respect...
# 4  stori children hyacinth dominican plant faith ...
#
#                                           tags_lemma
# 0  take fascinating key aspect seuss career poetr...
# 1  resource include principle understand small ch...
# 2  find life spin control death husband turn mini...
# 3  church christ biblical ecclesiology today resp...
# 4  story child hyacinth dominican plant faith pol...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143505 entries, 0 to 143504
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Title         143505 non-null  object
#  1   authors       141755 non-null  object
#  2   categories    137888 non-null  object
#  3   tags          143505 non-null  object
#  4   stemmed_tags  143390 non-null  object
#  5   tags_lemma    143390 non-null  object
# dtypes: object(6)
# memory usage: 6.6+ MB

# %%
books=books[~books['tags_lemma'].isnull()]

# %%
books['tokenized'] = books['tags_lemma'].apply(lambda x: x.split())

# %%
#REMOVE RARE TOKENS

# Calculate word frequencies
all_tokens = [token for tokens_list in books['tokenized'] for token in tokens_list]
word_counts = Counter(all_tokens)

# Print rare words
threshold = 5
rare_tokens = {token for token, count in word_counts.items() if count < threshold}
print("Rare Words:", rare_tokens)

# Remove rare words (e.g., occurring less than 10 times)
common_tokens = {token for token, count in word_counts.items() if count >= threshold}

# Update the 'tokens' column with only common tokens
books['tokenized'] = books['tokenized'].apply(lambda tokens_list: [token for token in tokens_list if token in common_tokens])
# Out:
# Rare Words: {'eclosion', 'tragedians', 'patke', '18d', 'haswritten', 'tatoo', 'potteries', 'recensenten', 'rizka', 'epigrammatist', 'jk', 'clausurando', 'explantation', 'parasitologyparasitesymbiont', 'coller', 'varner', 'firethorn', 'oorsprongkelijke', 'jubilatoire', 'liesbrock', 'gottesman', 'arditti', 'glenvane', 'kanaal', 'ferent', 'lucknow', 'canuck', 'thallon', 'valleroy', 'triangulate', 'changeover', 'clarabella', 'poprular', 'colorblindness', 'marseillais', 'paran', 'weisgard', 'phacoemulsification', 'ketika', 'rogozhin', 'marshay', 'disburse', 'auchentoshan', 'meandri', 'c3s', 'panchali', 'festus', 'maciel', 'eochaid', 'digeronimo', 'hokubei', 'apologeet', 'cyberfeminist', 'dionysos', 'xivs', 'kosygin', 'imix', 'pdap', 'cantabile', 'comparible', 'savoye', 'serversuse', 'ehrliche', 'extender', 'charoset', 'fordevelope', 'reparative', 'tcms', '1f', 'implemenation', 'kitaylizzie', 'reintroduces', 'sorenstam', 'acacia', 'neverlin', 'carnicer', 'curare', 'onderhielden', 'mullaney', 'tambora', 'christain', 'nikolas', 'pangaia', 'thinkingin', 'nonreligion', 'overbreng', 'famland', 'doshas', 'extoplanet', 'breathes', 'dabney', 'uglow', 'elrington', 'riflesautomatic', 'rupnik', 'husmanskost', 'clusterhaven', 'dimitriu', 'capetian', 'yamashita', 'presocratics', 'nazaire', 'beula', 'gevecht', 'kacey', 'huong', 'benokraitis', 'holomorphic', 'unde', 'enflame', 'chari', 'chromatically', 'belittling', 'transgenderism', 'stane', 'jsubject', 'komst', 'luntz', 'winell', 'didato', 'acercarse', 'undercutting', 'afficionado', 'backgroundf', 'unidroit', 'c9', 'duction', 'comenzaron', 'rsearche', 'morfolog', 'jinmen', 'chpt', 'slc', 'thiep', 'gibbe', 'piaffe', 'couplehood', 'gerontius', 'afflicter', 'arithmetician', 'picodon', 'goju', 'kristian', 'emphathic', 'thinner', 'whatyour', 'knitlit', 'examiners', 'mathis', 'exklusiv', 'melnik', 'hoofbeats', 'perzi', 'asguaw', 'guadagnini', 'chantaje', 'knockaround', 'gfpe', 'threeyear', 'haller', 'yejide', 'sobrepasar', 'adderall', 'fj25', 'engeler', 'invasionsomr', 'taghert', 'gallienne', 'bodacious', 'healthways', 'hafer', 'tanti', 'toothed', 'turba', 'andmicrochip', 'anagkazo', 'desvelado', 'embraer', 'classics661', 'ressemblance', 'kullervo', 'fabtasy', 'signified', 'latie', 'transcriptioncareer', 'bernardone', 'khaan', 'causalsystem', 'mnetapolicy', 'repetto', 'garmus', 'camoflauge', 'druh', 'colleagues', 'asad', 'dummkopf', 'alack', 'prehospitalaria', 'lygren', 'barberxxiii', 'humus', 'cryptarithm', 'velocitie', 'tijdlijn', 'bonastia', 'saikaku', 'metacomet', 'wythenshawe', 'scoffield', 'fantasitic', 'goebeler', 'skirting', 'clickapudi', 'reformalization', 'yodeler', 'wihtout', 'hormonally', 'pcrc', 'computus', 'sede', 'valv', 'jare', 'authorised', 'sut', 'thatdemolishe', 'eworking', 'immortalized', 'zumikon', 'kirwin', 'erudiete', 'debting', 'morg', 'ringcraft', 'gerstenlauer', 'negrin', 'dispassionately', 'aos', 'nobleza', 'retruend', 'tannh', 'unmystified', 'alternatieve', 'ferential', 'dramatistic', 'kennell', 'modernos', 'harline', 'bacteriology', 'psychopharmo', 'mcpd', 'muskogean', 'lunenburg', 'dairil', 'stevent', 'doppelt', 'gospodinov', 'hanzi', 'booklista', 'wonderlandthe', 'moreoever', 'guelphlinda', 'chapatis', 'daf', 'archaist', 'olin', 'bunraku', 'buitenaardse', 'enfatiz', 'dentiality', 'nyanasobhano', 'ticketmastermonopoly', 'epoc', 'interferometric', 'screamed', 'raissuli', 'bjorkman', 'demonisation', 'oiefe', 'apsara', 'myenne', 'berceo', 'bankmen', 'phic', 'dantean', 'darknessthe', 'istance', 'xiaolin', 'aquariums', 'keyd', 'jerard', 'contentsj', 'tilefish', 'supercharging', 'verwende', 'commmander', 'waber', 'erotismo', 'experienceis', 'varietyof', 'stockport', 'engineeringpress', 'dt50', 'supereme', 'dunford', 'urfa', 'islay', 'tegemoet', 'bestrijden', 'tuskegg', 'unsupportive', 'iciar', 'bewondere', 'mohave', 'tumbled', 'surfari', 'inmoral', 'pfte', 'vezina', 'sprak', 'alentara', 'statistico', 'lakeland', 'newpractice', 'frijole', 's100', 'kovno', 'divest', 'spellcast',  ...

# %%
len(rare_tokens)
# Out:
# 117022

# %%
len(all_tokens)
# Out:
# 7130770

# %%
#REMOVE SOME OF THE TOO FREQUENT TOKENS
#Finding the frequency of the tokens in the corpus
token_frequency = books['tokenized'].explode().value_counts()

# %%
token_frequency[1:100]
# Out:
# tokenized
# life       41687
# include    36712
# work       32874
# story      28222
# year       27238
#            ...
# turn        7330
# process     7323
# english     7308
# play        7217
# form        7143
# Name: count, Length: 99, dtype: int64

# %%
#selecting the tokens (these are the words common across book descriptions, indiscriminate of the genre of the book)
unwanted_tokens = ['book','include','author','year','time','reader','edition','offer','great','day','text','cover','read','understand','feature','chapter','volume','bring','provide','publish']

# %%
#Removing those tokens from the corpus
books['tokenized'] = books['tokenized'].apply(lambda tokens: [token for token in tokens if token not in unwanted_tokens])

# %%
#Processing authors and category
books['categories'].fillna(value=' ', inplace=True)
books['authors'].fillna(value = ' ',inplace=True)

# %%
def collapse(L):
    L1 = ''
    for i in L:
        L1 = L1+ i.replace(" ","")
    return L1

# %%
books['authors'] = books['authors'].apply(lambda x: collapse(x))
books['categories'] = books['categories'].apply(lambda x: collapse(x))

# %%
# Function to convert to string, handling empty strings
import ast
def tokens_string(s):
    try:
        lst = ast.literal_eval(s)
        if isinstance(lst, list) and len(lst) > 0:
            return ' '.join(lst)
        else:
            return ''
    except (SyntaxError, ValueError):
        return ''

# %%
books['cat'] = books['categories'].apply(lambda x: tokens_string(x))
books['auth'] = books['authors'].apply(lambda x: tokens_string(x))
books['tok'] = books['tokenized'].apply(lambda tokens: ' '.join(tokens))

# %%
books['tags'] = books['cat'] +' ' +books['auth'] + ' ' + books['tok']

# %%
books['tags_tokens'] = books['tags'].apply(lambda x: x.split())

# %%
books.head()
# Out:
#                                                Title                 authors  \
# 0                           Dr. Seuss: American Icon            [Philip Nel]
# 1              Wonderful Worship in Smaller Churches          [David R. Ray]
# 2                      Whispers of the Wicked Saints       [Veronica Haddon]
# 3  The Church of Christ: A Biblical Ecclesiology ...      [Everett Ferguson]
# 4                           Saint Hyacinth of Poland  [Mary Fabyan Windeatt]
#
#                     categories  \
# 0  [Biography & Autobiography]
# 1                   [Religion]
# 2                    [Fiction]
# 3                   [Religion]
# 4  [Biography & Autobiography]
#
#                                                 tags  \
# 0  Biography&Autobiography PhilipNel take fascina...
# 1  Religion DavidR.Ray resource principle small c...
# 2  Fiction VeronicaHaddon find life spin control ...
# 3  Religion EverettFerguson church christ biblica...
# 4  Biography&Autobiography MaryFabyanWindeatt sto...
#
#                                         stemmed_tags  \
# 0  take fascin key aspect seuss career poetri pol...
# 1  resourc includ principl understand small churc...
# 2  find life spin control death husband turn mini...
# 3  church christ biblic ecclesiolog today respect...
# 4  stori children hyacinth dominican plant faith ...
#
#                                           tags_lemma  \
# 0  take fascinating key aspect seuss career poetr...
# 1  resource include principle understand small ch...
# 2  find life spin control death husband turn mini...
# 3  church christ biblical ecclesiology today resp...
# 4  story child hyacinth dominican plant faith pol...
#
#                                            tokenized                auth  \
# 0  [take, fascinating, key, aspect, seuss, career...           PhilipNel
# 1  [resource, principle, small, church, worship, ...          DavidR.Ray
# 2  [find, life, spin, control, death, husband, tu...      VeronicaHaddon
# 3  [church, christ, biblical, ecclesiology, today...     EverettFerguson
# 4  [story, child, hyacinth, dominican, plant, fai...  MaryFabyanWindeatt
#
#                        cat                                                tok  \
# 0  Biography&Autobiography  take fascinating key aspect seuss career poetr...
# 1                 Religion  resource principle small church worship practi...
# 2                  Fiction  find life spin control death husband turn mini...
# 3                 Religion  church christ biblical ecclesiology today resp...
# 4  Biography&Autobiography  story child hyacinth dominican plant faith pol...
#
#                                          tags_tokens
# 0  [Biography&Autobiography, PhilipNel, take, fas...
# 1  [Religion, DavidR.Ray, resource, principle, sm...
# 2  [Fiction, VeronicaHaddon, find, life, spin, co...
# 3  [Religion, EverettFerguson, church, christ, bi...
# 4  [Biography&Autobiography, MaryFabyanWindeatt, ...

# %%
features = ['Title','tags','tags_tokens']

# %%
new = books[features]

# %%
new.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                                                 tags  \
# 0  Biography&Autobiography PhilipNel take fascina...
# 1  Religion DavidR.Ray resource principle small c...
# 2  Fiction VeronicaHaddon find life spin control ...
# 3  Religion EverettFerguson church christ biblica...
# 4  Biography&Autobiography MaryFabyanWindeatt sto...
#
#                                          tags_tokens
# 0  [Biography&Autobiography, PhilipNel, take, fas...
# 1  [Religion, DavidR.Ray, resource, principle, sm...
# 2  [Fiction, VeronicaHaddon, find, life, spin, co...
# 3  [Religion, EverettFerguson, church, christ, bi...
# 4  [Biography&Autobiography, MaryFabyanWindeatt, ...

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143390 entries, 0 to 143504
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Title        143390 non-null  object
#  1   tags         143390 non-null  object
#  2   tags_tokens  143390 non-null  object
# dtypes: object(3)
# memory usage: 4.4+ MB

# %%
# new.to_csv('../data/lemma_preprocessed.csv',index=False)

# %% [markdown]
# *END*
